# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/healthcare_data.csv')
df.head()
# Out:
#    Patient_ID    Patient_Name  Age  Gender Blood_Type      Diagnosis  \
# 0        1001      John Smith   45    Male         A+   Hypertension
# 1        1002        Jane Doe   62  Female         B-       Diabetes
# 2        1003  Robert Johnson   35    Male         O+         Cancer
# 3        1004    Susan Wilson   78  Female         A-  Heart Disease
# 4        1005   Michael Brown   55    Male        AB+         Asthma
#
#    Treatment_Cost
# 0         1200.50
# 1          800.75
# 2         5500.00
# 3         2700.25
# 4          400.00

# %%
df
# Out:
#     Patient_ID          Patient_Name  Age  Gender Blood_Type      Diagnosis  \
# 0         1001            John Smith   45    Male         A+   Hypertension
# 1         1002              Jane Doe   62  Female         B-       Diabetes
# 2         1003        Robert Johnson   35    Male         O+         Cancer
# 3         1004          Susan Wilson   78  Female         A-  Heart Disease
# 4         1005         Michael Brown   55    Male        AB+         Asthma
# 5         1006           Lisa Miller   30  Female         B+   Hypertension
# 6         1007           James Davis   48    Male         O-       Diabetes
# 7         1008          Karen Harris   65  Female        AB-         Cancer
# 8         1009          David Wilson   72    Male         A+  Heart Disease
# 9         1010           Linda Smith   42  Female         O+         Asthma
# 10        1011           William Lee   33    Male        AB+   Hypertension
# ...

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Patient_Name', 'Age', 'Gender', 'Blood_Type',
#        'Diagnosis', 'Treatment_Cost'],
#       dtype='object')

# %%
df[["Age"]].plot.hist(bins=12, alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# <hr>

# %%
df.shape
# Out:
# (50, 7)

# %%
df[df['Gender'] == 'Male'].count()
# Out:
# Patient_ID        25
# Patient_Name      25
# Age               25
# Gender            25
# Blood_Type        25
# Diagnosis         25
# Treatment_Cost    19
# dtype: int64

# %%
(25/50)*100
# Out:
# 50.0

# %% [markdown]
# <p>50% of the patients are male.</p>

# %% [markdown]
# <hr>

# %%
df2 = df[df['Diagnosis'] == 'Cancer']

# %%
df2.shape
# Out:
# (10, 7)

# %% [markdown]
# <p>There are 10 patients diagnosed with cancer.</p>
# <hr>

# %%
df3 = df.drop(columns =['Patient_ID'])

# %%
df3[df['Age'] > 59].describe()
# Out:
#              Age  Treatment_Cost
# count  12.000000         8.00000
# mean   66.416667      2344.59375
# std     5.230302      1799.18809
# min    60.000000       800.75000
# 25%    62.000000       872.75000
# 50%    65.000000      1912.75000
# 75%    70.000000      3225.00000
# max    78.000000      5900.00000

# %% [markdown]
# <p>The average treatment cost for patients 60 and above is 2344.59375.</p>
# <hr>

# %%
df4 = df.groupby(['Blood_Type'])[['Treatment_Cost']].mean()

# %%
df4.idxmax()
# Out:
# Treatment_Cost    A+
# dtype: object

# %% [markdown]
# The blood type with the highest average treatment cost is A+.

# %% [markdown]
# <hr>

# %%
df5 = df.drop(columns =['Patient_ID', 'Treatment_Cost'])

# %%
df5.groupby(['Gender', 'Diagnosis']).mean()
# Out:
# C:\Users\robyn\AppData\Local\Temp\ipykernel_1880\3757681515.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df5.groupby(['Gender', 'Diagnosis']).mean()
#                             Age
# Gender Diagnosis
# Female Asthma         47.666667
#        Cancer         55.333333
#        Diabetes       54.400000
#        Heart Disease  57.750000
#        Hypertension   45.250000
# Male   Asthma         49.000000
#        Cancer         44.500000
#        Diabetes       52.000000
#        Heart Disease  54.666667
#        Hypertension   39.166667

# %% [markdown]
# <hr>
